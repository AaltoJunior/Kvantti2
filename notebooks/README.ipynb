# %% [markdown]
# # Salaisuuksia ja Bittejä
#
# Suomenkieleiseen työpajaan pääset [tästä!](FI/fi_koodi.ipynb)

# %% [markdown]
# # Introduction to encryption
#
# Access the English workshop [here!](EN/en_code.ipynb)
